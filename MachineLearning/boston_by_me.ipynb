# %%
import numpy as np
import pandas as pd
from matplotlib.pyplot import subplots
from ISLP import load_data
from ISLP.models import (ModelSpec as MS,
                         summarize,
                         poly)
import statsmodels.api as sm

# %%
# read csv file
data = pd.read_csv("HousingData.csv")
data.columns
# convertir a minusculas
data.columns = [x.lower() for x in data.columns]
data.columns

# %%
data_boston = load_data("Boston")
columns_boston = data_boston.columns
columns_boston

# tomas todo expepto la ultima
y = data_boston['medv']

intercept = pd.DataFrame({'intercept': np.ones(data_boston.shape[0])})

X = pd.concat([intercept, data_boston[columns_boston[:-1]]], axis=1)

X
# Out:
#      intercept     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0          1.0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1          1.0  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2          1.0  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3          1.0  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4          1.0  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..         ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501        1.0  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502        1.0  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503        1.0  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504        1.0  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505        1.0  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio  lstat
# 0    296     15.3   4.98
# ...

# %%
model = sm.OLS(y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   medv   R-squared:                       0.734
# Model:                            OLS   Adj. R-squared:                  0.728
# Method:                 Least Squares   F-statistic:                     113.5
# Date:                Tue, 28 Nov 2023   Prob (F-statistic):          2.23e-133
# Time:                        20:44:46   Log-Likelihood:                -1504.9
# No. Observations:                 506   AIC:                             3036.
# Df Residuals:                     493   BIC:                             3091.
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     41.6173      4.936      8.431      0.000      31.919      51.316
# ...

# %%
data_boston.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    lstat  medv
# 0   4.98  24.0
# 1   9.14  21.6
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2
