# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## **1. Un banco considera como default a las operaciones con mora mayor a 90 dias. Proyectar la evolución de la probabilidad de default para el escenario en "5_dataset_default.csv".**

# %%
df = pd.read_csv('./5_dataset_default.csv', )

df.head()
# Out:
#             0               1              2              3
# 0  id_cliente  monto_original    mora_202201    mora_202301
# 1           1           20000      1) 0 dias  3) 30-60 dias
# 2           2          120000  3) 30-60 dias      1) 0 dias
# 3           3           90000      1) 0 dias      1) 0 dias
# 4           4           50000      1) 0 dias      1) 0 dias

# %%
transition_matrix = [
    
]

# %% [markdown]
# ## **2. Simular la evolución del conteo de problación. Para esto considerar que el limite mínimo de individuos es 0 y el límite máximo de individuos es 100. Las tasas de nacimiento y muerte se han estimado en 0.005. El estado inicial de la población es 25 individuos.**
