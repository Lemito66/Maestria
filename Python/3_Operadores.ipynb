# %% [markdown]
# # Cualquier cosa que no es 0 es True

# %%
int(True) + True
# Out:
# 2

# %%
if 2:
    print('True')
# Out:
# True

# %%
# Suma
5 + 5
# Out:
# 10

# %%
5**2
# Out:
# 25

# %%
5 / 6
# Out:
# 0.8333333333333334

# %% [markdown]
# # Mi Jupyter Notebook – Clase 2

# %% [markdown]
# **Emill Logroño** <br>
# Analista de datos

# %% [markdown]
# *Me gustaría aprender análisis de datos para poder tomar decisiones en base a datos.*

# %% [markdown]
# ### A continuación visualizaremos una suma de dos números.

# %% [markdown]
# `1 + 1`

# %%
1 + 1
# Out:
# 2

# %% [markdown]
# 1. Uno
# 2. Dos
# 3. Tres
# * Primero
# * Segundo
# * Tercer
# * Cuarto
# ---
# [Mi GitHub](https://github.com/Lemito66) <br>
# | ID | Nombre |
# | ----------- | ----------- |
# | 1 | Emill |
# | 2 | Jorge |
#
# <br>
# Emoji! 🤔
#
# - [x] Quito
# - [ ] Guayaquil
# - [ ] Cuenca
